# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatesh176/AI_Training/blob/GenAI/SVC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, scale
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.decomposition import PCA
from sklearn.utils import resample

# %%
df = pd.read_excel('https://archive.ics.uci.edu/ml/machine-learning-databases/00350/default%20of%20credit%20card%20clients.xls?utm_source=chatgpt.com',
                   header = 1)

# %%
df.head()
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
df.rename({'default payment next month': 'DEFAULT'}, axis = 'columns', inplace = True)
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  ...  PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# 0   1      20000    2          2  ...         0         0         0        1
# 1   2     120000    2          2  ...      1000         0      2000        1
# 2   3      90000    2          2  ...      1000      1000      5000        0
# 3   4      50000    2          2  ...      1100      1069      1000        0
# 4   5      50000    1          2  ...      9000       689       679        0
#
# [5 rows x 25 columns]

# %%
df.drop('ID', axis = 1, inplace = True)
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  ...  PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# 0      20000    2          2         1  ...         0         0         0        1
# 1     120000    2          2         2  ...      1000         0      2000        1
# 2      90000    2          2         2  ...      1000      1000      5000        0
# 3      50000    2          2         1  ...      1100      1069      1000        0
# 4      50000    1          2         1  ...      9000       689       679        0
#
# [5 rows x 24 columns]

# %%
df.dtypes
# Out:
# LIMIT_BAL    int64
# SEX          int64
# EDUCATION    int64
# MARRIAGE     int64
# AGE          int64
# PAY_0        int64
# PAY_2        int64
# PAY_3        int64
# PAY_4        int64
# PAY_5        int64
# PAY_6        int64
# BILL_AMT1    int64
# BILL_AMT2    int64
# BILL_AMT3    int64
# BILL_AMT4    int64
# BILL_AMT5    int64
# BILL_AMT6    int64
# PAY_AMT1     int64
# PAY_AMT2     int64
# PAY_AMT3     int64
# PAY_AMT4     int64
# PAY_AMT5     int64
# PAY_AMT6     int64
# DEFAULT      int64
# dtype: object

# %%
df['SEX'].unique()
# Out:
# array([2, 1])

# %%
df['EDUCATION'].unique()
# Out:
# array([2, 1, 3, 5, 4, 6, 0])

# %%
df['MARRIAGE'].unique()
# Out:
# array([1, 2, 3, 0])

# %%
len(df.loc[(df['EDUCATION'] == 0) | (df['MARRIAGE'] == 0)])
# Out:
# 68

# %%
len(df)
# Out:
# 30000

# %%
df_no_missing = df.loc[(df['EDUCATION'] != 0) & (df['MARRIAGE'] != 0)]

# %%
len(df_no_missing)
# Out:
# 29932

# %%
df_no_missing['EDUCATION'].unique()
# Out:
# array([2, 1, 3, 5, 4, 6])

# %%
df_no_missing['MARRIAGE'].unique()
# Out:
# array([1, 2, 3])

# %%
df_no_default = df_no_missing[df_no_missing['DEFAULT'] == 0]
df_default = df_no_missing[df_no_missing['DEFAULT'] == 1]

# %%
df_no_default_downsampled = resample(df_no_default,
                                     replace = False,
                                     n_samples = 1000,
                                     random_state = 42)

# %%
df_default_downsampled = resample(df_default,
                                     replace = False,
                                     n_samples = 1000,
                                     random_state = 42)

# %%
len(df_no_default_downsampled)
len(df_default_downsampled)
# Out:
# 1000

# %%
df_downsample = pd.concat([df_no_default_downsampled,df_default_downsampled ])
len(df_downsample)
# Out:
# 2000

# %%
X = df_downsample.drop('DEFAULT', axis = 1).copy()
X.head()
# Out:
#        LIMIT_BAL  SEX  EDUCATION  ...  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 641       130000    2          3  ...         0         0         0
# 4678      170000    1          3  ...      1200      1500      1300
# 16004     180000    2          2  ...      1056       950      1000
# 22974     210000    2          2  ...         0         0         0
# 17535     190000    2          3  ...      2663      2751      3000
#
# [5 rows x 23 columns]

# %%
y = df_downsample['DEFAULT'].copy()
y.head()
# Out:
# 641      0
# 4678     0
# 16004    0
# 22974    0
# 17535    0
# Name: DEFAULT, dtype: int64

# %%
pd.get_dummies(X, columns=['MARRIAGE']).head()
# Out:
#        LIMIT_BAL  SEX  EDUCATION  ...  MARRIAGE_1  MARRIAGE_2  MARRIAGE_3
# 641       130000    2          3  ...        True       False       False
# 4678      170000    1          3  ...        True       False       False
# 16004     180000    2          2  ...        True       False       False
# 22974     210000    2          2  ...       False        True       False
# 17535     190000    2          3  ...        True       False       False
#
# [5 rows x 25 columns]

# %%
X_encoded = pd.get_dummies(X, columns=['SEX',
                                       'EDUCATION',
                                       'MARRIAGE',
                                       'PAY_0',
                                       'PAY_2',
                                       'PAY_3',
                                       'PAY_4',
                                       'PAY_5'])
X_encoded.head()
# Out:
#        LIMIT_BAL  AGE  PAY_6  BILL_AMT1  ...  PAY_5_4  PAY_5_5  PAY_5_6  PAY_5_7
# 641       130000   28     -2     100143  ...    False    False    False    False
# 4678      170000   29      0     165027  ...    False    False    False    False
# 16004     180000   29      0      25781  ...    False    False    False    False
# 22974     210000   32     -2        355  ...    False    False    False    False
# 17535     190000   45      0      76433  ...    False    False    False    False
#
# [5 rows x 73 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size =0.2, random_state = 42)
X_train_scaled = scale(X_train)
X_test_scaled = scale(X_test)

# %%
clf_svm = SVC(random_state = 42)
clf_svm.fit(X_train_scaled, y_train)
# Out:
# SVC(random_state=42)

# %%
ConfusionMatrixDisplay.from_estimator(clf_svm, X_test_scaled, y_test)

# %%
confusion_matrix(y_test, clf_svm.predict(X_test_scaled))
# Out:
# array([[154,  45],
#        [ 87, 114]])

# %%
param_grid = [
    {'C': [0.1,1,10,100],
     'gamma': ['scale', 1, 0.1, 0.01,  0.001, 0.0001],
     'kernel': ['rbf']}
]

# %%
optimal_params = GridSearchCV(
                              SVC(),
                              param_grid,
                              cv =5,
                              scoring = 'accuracy',
                              verbose = 0)
optimal_params.fit(X_train_scaled, y_train)
print(optimal_params.best_params_)
# Out:
# {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
clf_svm = SVC(random_state=42, C = 100, gamma = 0.001)
clf_svm.fit(X_train_scaled, y_train)
# Out:
# SVC(C=100, gamma=0.001, random_state=42)

# %%
ConfusionMatrixDisplay.from_estimator(clf_svm, X_test_scaled, y_test)

# %%
len(df_downsample.columns)
# Out:
# 24

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_train_scaled)
y_trimmed = y[:1600]

# Step 5: Plot the PCA result
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_trimmed, cmap='viridis', edgecolor='k', s=60)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA - 2D Projection')
plt.legend(*scatter.legend_elements(), title="Classes")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
train_pc1 = X_pca[:,0]
train_pc2 = X_pca[:,1]

pca_train_scaled = scale(np.column_stack((train_pc1, train_pc2)))

param_grid = [
    {'C': [1,10,100, 1000],
     'gamma': ['scale', 1, 0.1, 0.01,  0.001, 0.0001],
     'kernel': ['rbf']}
]

optimal_params = GridSearchCV(
                              SVC(),
                              param_grid,
                              cv =5,
                              scoring = 'accuracy',
                              verbose = 0)
optimal_params.fit(pca_train_scaled , y_train)
print(optimal_params.best_params_)
# Out:
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
clf_svm = SVC(random_state=42, C=1000, gamma = 'scale')
clf_svm.fit(pca_train_scaled, y_train)
# Out:
# SVC(C=1000, random_state=42)

# %%
X_test_pca = pca.transform(X_test_scaled)
test_pc1 = X_test_pca[:,0]
test_pc2 = X_test_pca[:,1]
pca_test_scaled = scale(np.column_stack((test_pc1, test_pc2)))


ConfusionMatrixDisplay.from_estimator(clf_svm, pca_test_scaled, y_test)
